# %% [markdown]
# # 📊 Cryptocurrency Data Analysis Project
#
# ## Project Overview
# This notebook performs comprehensive data cleaning and preprocessing on a cryptocurrency dataset containing information about 4,150 cryptocurrencies. The analysis includes handling missing values, data type conversions, and statistical imputation techniques to prepare the data for further analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Setup and Data Loading
# In this section, we mount Google Drive to access our dataset and import the necessary Python libraries for data manipulation and visualization. We then load the cryptocurrency dataset from a CSV file stored in Google Drive.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CryptocurrencyData.csv')

# %%
df
# Out:
#       Rank    Coin Name Symbol     Price       1h      24h       7d      30d  \
# 0        1      Bitcoin    BTC  36,456.94   0.40%   -1.70%    1.00%   18.40%
# 1        2     Ethereum    ETH   2,027.60   0.50%    1.40%    1.00%   20.70%
# 2        3       Tether   USDT       1.00   0.10%   -0.30%   -0.10%   -0.10%
# 3        4          BNB    BNB     231.63  -0.10%  -12.60%   -8.00%    5.40%
# 4        5          XRP    XRP       0.59   0.10%   -1.90%   -6.90%   12.10%
# ...    ...          ...    ...        ...     ...      ...      ...      ...
# 4145  4146  Aave DAI v1   ADAI       1.00  -0.20%   -0.50%   -1.20%   -1.10%
# 4146  4147  Hive Dollar    HBD       0.97   0.20%   -3.20%   -3.10%   -3.60%
# 4147  4148    OWN Token    OWN      $-     -0.20%    0.00%   -0.20%   -0.10%
# 4148  4149   Kmushicoin    KTV       0.52       -        -        -        -
# 4149  4150    XCF Token    XCF      $-      0.10%    0.80%  -70.90%  -77.80%
#
#               24h Volume  Circulating Supply  Total Supply  \
# 0     $22,801,222,945.00          19,549,806    21 Million
# 1     $26,845,710,464.00         120,249,015   120 Million
# 2     $47,122,466,339.00      88,308,652,879  88.3 Billion
# 3      $3,715,265,116.00         153,856,150   154 Million
# 4      $1,339,890,506.00      53,718,306,475   100 Billion
# ...                   ...                ...           ...
# 4145              $58.60                   0             -
# 4146         $140,416.00                   0             -
# 4147               $0.60                   0     5 Billion
# 4148                   -                   0    20 Million
# 4149              $43.61                   0   1.5 Billion
#
#                Market Cap
# 0     $712,726,163,003.00
# 1     $243,488,187,281.00
# 2      $88,027,617,310.00
# 3      $35,716,332,862.00
# 4      $31,863,926,051.00
# ...                    ...
# 4145                    -
# 4146                    -
# 4147                    -
# 4148                    -
# 4149                    -
#
# [4150 rows x 12 columns]

# %% [markdown]
# ## 2. Initial Data Exploration
#
# We examine the dataset structure, data types, and check the first few rows to understand what information is available. The dataset contains 12 columns including rank, coin name, symbol, price, percentage changes (1h, 24h, 7d, 30d), trading volume, supply metrics, and market capitalization.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4150 entries, 0 to 4149
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                4150 non-null   int64
#  1   Coin Name           4150 non-null   object
#  2   Symbol              4150 non-null   object
#  3    Price              4150 non-null   object
#  4   1h                  4055 non-null   object
#  5   24h                 4150 non-null   object
#  6   7d                  4148 non-null   object
#  7   30d                 4093 non-null   object
#  8    24h Volume         4150 non-null   object
#  9   Circulating Supply  4150 non-null   object
#  10  Total Supply        4150 non-null   object
#  11   Market Cap         4150 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 389.2+ KB

# %%
df.columns
# Out:
# Index(['Rank', 'Coin Name', 'Symbol', ' Price ', '1h', '24h', '7d', '30d',
#        ' 24h Volume ', 'Circulating Supply', 'Total Supply', ' Market Cap '],
#       dtype='object')

# %%
# Changing column names
df = df.rename(columns={
    'Rank':'Rank',
    'Coin_name':'Coin_name',
    'Symbol':'Symbol',

    ' Price ':'Price($)',

    '1h':'Change_1h(%)',
    '24h':'Change_24h(%)',
    '7d':'Change_7d(%)',
    '30d':'Change_30d(%)',

    ' 24h Volume ':'Volume_24h($)',
    'Circulating Supply':'Circulating_Supply',
    ' Market Cap ':'Market_Cap($)'
})

# %%
df.head()
# Out:
#    Rank Coin Name Symbol   Price($) Change_1h(%) Change_24h(%) Change_7d(%)  \
# 0     1   Bitcoin    BTC  36,456.94        0.40%        -1.70%        1.00%
# 1     2  Ethereum    ETH   2,027.60        0.50%         1.40%        1.00%
# 2     3    Tether   USDT       1.00        0.10%        -0.30%       -0.10%
# 3     4       BNB    BNB     231.63       -0.10%       -12.60%       -8.00%
# 4     5       XRP    XRP       0.59        0.10%        -1.90%       -6.90%
#
#   Change_30d(%)        Volume_24h($) Circulating_Supply  Total Supply  \
# 0        18.40%  $22,801,222,945.00          19,549,806    21 Million
# 1        20.70%  $26,845,710,464.00         120,249,015   120 Million
# 2        -0.10%  $47,122,466,339.00      88,308,652,879  88.3 Billion
# 3         5.40%   $3,715,265,116.00         153,856,150   154 Million
# 4        12.10%   $1,339,890,506.00      53,718,306,475   100 Billion
#
#           Market_Cap($)
# 0  $712,726,163,003.00
# 1  $243,488,187,281.00
# 2   $88,027,617,310.00
# 3   $35,716,332,862.00
# 4   $31,863,926,051.00

# %%
# Print each column name with its exact representation
for col in df.columns:
    print(repr(col))
# Out:
# 'Rank'
# 'Coin Name'
# 'Symbol'
# 'Price($)'
# 'Change_1h(%)'
# 'Change_24h(%)'
# 'Change_7d(%)'
# 'Change_30d(%)'
# 'Volume_24h($)'
# 'Circulating_Supply'
# 'Total Supply'
# 'Market_Cap($)'

# %%
df.isnull().sum()/len(df)*100
# Out:
# Rank                  0.000000
# Coin Name             0.000000
# Symbol                0.000000
# Price($)              0.000000
# Change_1h(%)          2.289157
# Change_24h(%)         0.000000
# Change_7d(%)          0.048193
# Change_30d(%)         1.373494
# Volume_24h($)         0.000000
# Circulating_Supply    0.000000
# Total Supply          0.000000
# Market_Cap($)         0.000000
# dtype: float64

# %% [markdown]
# ## **Cleaning rows** ($,%,-," " ,etc) and **converting their dtypes**

# %%
# Helper function to clean and convert columns to numeric
def clean_and_convert(series):
    if series.dtype == 'object':
        # Convert to string to ensure .str accessor works
        cleaned_series = series.astype(str)

        # Remove common non-numeric characters like '$', ',', '%'
        cleaned_series = cleaned_series.str.replace('$', '', regex=False)
        cleaned_series = cleaned_series.str.replace(',', '', regex=False)
        cleaned_series = cleaned_series.str.replace('%', '', regex=False)

        # Replace '-' or any non-numeric string with NaN before converting
        # This regex will catch '-', '$-', etc. that are not valid numbers
        cleaned_series = cleaned_series.replace(r'^\s*[-]+(?:\s*\-)*\s*$', np.nan, regex=True)
        cleaned_series = cleaned_series.replace(r'^\s*$', np.nan, regex=True) # Matches empty strings

        # Convert to numeric, coercing errors will turn unconvertible values into NaN
        return pd.to_numeric(cleaned_series, errors='coerce')
    else:
        return series # If already numeric, return as is

# Columns identified for cleaning and conversion
columns_to_process = [
    'Price($)',
    'Change_1h(%)',
    'Change_24h(%)',
    'Change_7d(%)',
    'Change_30d(%)',
    'Volume_24h($)',
    'Circulating_Supply',
    'Market_Cap($)'
]

for col in columns_to_process:
    df[col] = clean_and_convert(df[col])

df.head(10)
# Out:
#    Rank          Coin Name Symbol  Price($)  Change_1h(%)  Change_24h(%)  \
# 0     1            Bitcoin    BTC  36456.94           0.4           -1.7
# 1     2           Ethereum    ETH   2027.60           0.5            1.4
# 2     3             Tether   USDT      1.00           0.1           -0.3
# 3     4                BNB    BNB    231.63          -0.1          -12.6
# 4     5                XRP    XRP      0.59           0.1           -1.9
# 5     6               USDC   USDC      1.00           0.0           -0.4
# 6     7             Solana    SOL     54.97           0.6           -0.6
# 7     8  Lido Staked Ether  STETH   2023.81           0.4            1.5
# 8     9            Cardano    ADA      0.37           0.1           -1.6
# 9    10           Dogecoin   DOGE      0.07           0.1           -2.3
#
#    Change_7d(%)  Change_30d(%)  Volume_24h($)  Circulating_Supply  \
# 0           1.0           18.4   2.280122e+10        1.954981e+07
# 1           1.0           20.7   2.684571e+10        1.202490e+08
# 2          -0.1           -0.1   4.712247e+10        8.830865e+10
# 3          -8.0            5.4   3.715265e+09        1.538562e+08
# 4          -6.9           12.1   1.339891e+09        5.371831e+10
# 5           0.0            0.0   1.645824e+10        2.426459e+10
# 6         -11.4           87.9   2.374980e+09        4.231043e+08
# 7           0.9           20.7   1.762554e+07        9.107771e+06
# 8           0.7           40.1   3.732770e+08        3.496474e+10
# 9           0.1           14.9   9.572257e+08        1.419356e+11
#
#    Total Supply  Market_Cap($)
# 0    21 Million   7.127262e+11
# 1   120 Million   2.434882e+11
# 2  88.3 Billion   8.802762e+10
# 3   154 Million   3.571633e+10
# 4   100 Billion   3.186393e+10
# 5  24.3 Billion   2.412008e+10
# 6   563 Million   2.325809e+10
# 7  9.11 Million   1.843532e+10
# 8    45 Billion   1.290396e+10
# 9   142 Billion   1.053291e+10

# %%
(df['Market_Cap($)']== 0).sum()
# Out:
# np.int64(0)

# %%
(df['Price($)']== 0).sum()
# Out:
# np.int64(0)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (4150, 12)
# Rank                     0
# Coin Name                0
# Symbol                   0
# Price($)              1726
# Change_1h(%)           547
# Change_24h(%)          452
# Change_7d(%)           454
# Change_30d(%)          509
# Volume_24h($)          484
# Circulating_Supply       0
# Total Supply             0
# Market_Cap($)          410
# dtype: int64

# %% [markdown]
# ## Filling NaN values

# %%
# filling NaN values using this formula
df['Price($)'] = df['Price($)'].fillna(
    df['Market_Cap($)'] / (df['Circulating_Supply']+ (0.0001))
)

# Filling market cap
df['Market_Cap($)'] = df['Market_Cap($)'].fillna(
    df['Price($)'] * df['Circulating_Supply']
)

# %%
# filling changes with 0.
cols = ['Change_1h(%)','Change_24h(%)','Change_7d(%)','Change_30d(%)']
for col in cols:
    df[col] = df[col].fillna(0)

# %%
df['Volume_24h($)'] = df['Volume_24h($)'].fillna(df['Volume_24h($)'].median())

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Coin Name               0
# Symbol                  0
# Price($)              248
# Change_1h(%)            0
# Change_24h(%)           0
# Change_7d(%)            0
# Change_30d(%)           0
# Volume_24h($)           0
# Circulating_Supply      0
# Total Supply            0
# Market_Cap($)         248
# dtype: int64

# %%
df.select_dtypes(include='number').skew()
# Out:
# Rank                   0.000000
# Price($)              33.306810
# Change_1h(%)          25.111441
# Change_24h(%)         11.909291
# Change_7d(%)          45.448084
# Change_30d(%)         63.679131
# Volume_24h($)         38.796482
# Circulating_Supply    60.414100
# Market_Cap($)         53.396721
# dtype: float64

# %%
# Let's check a sample of rows where Price is NaN
nan_price_rows = df[df['Price($)'].isna()]
print(f"Total rows with NaN price: {len(nan_price_rows)}")
print("\nSample of rows with NaN price:")
nan_price_rows[['Coin Name', 'Price($)', 'Market_Cap($)', 'Circulating_Supply']].head(10)
# Out:
# Total rows with NaN price: 248
#
# Sample of rows with NaN price:
#                            Coin Name  Price($)  Market_Cap($)  \
# 3740                          FrogeX       NaN            NaN
# 3741  Mainstream For The Underground       NaN            NaN
# 3743                       Bean Cash       NaN            NaN
# 3744                        Ratecoin       NaN            NaN
# 3746                      Casinocoin       NaN            NaN
# 3747                          Yocoin       NaN            NaN
# 3748                    LBRY Credits       NaN            NaN
# 3751                         Bitmark       NaN            NaN
# 3752                         Element       NaN            NaN
# 3754                         Geocoin       NaN            NaN
#
#       Circulating_Supply
# 3740               411.0
# 3741         788686598.0
# 3743                 0.0
# 3744                 0.0
# 3746                 0.0
# 3747                 0.0
# 3748                 0.0
# 3751                 0.0
# 3752                 0.0
# 3754                 0.0

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3902, 12)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Coin Name             0
# Symbol                0
# Price($)              0
# Change_1h(%)          0
# Change_24h(%)         0
# Change_7d(%)          0
# Change_30d(%)         0
# Volume_24h($)         0
# Circulating_Supply    0
# Total Supply          0
# Market_Cap($)         0
# dtype: int64

# %%
nan_price_rows = df[df['Price($)'].isna()]
print(f"Total rows with NaN price: {len(nan_price_rows)}")
print("\nSample of rows with NaN price:")
nan_price_rows[['Coin Name', 'Price($)', 'Market_Cap($)', 'Circulating_Supply']].head(10)
# Out:
# Total rows with NaN price: 0
#
# Sample of rows with NaN price:
# Empty DataFrame
# Columns: [Coin Name, Price($), Market_Cap($), Circulating_Supply]
# Index: []

# %% [markdown]
# # Data is totally cleaned
